# %% [markdown]
# # Statistics
# - Discriptive
# - Infrential
#
# 1. Discriptive Stastics:
#    -> Sumarizing, Analysing and visualizing Data.
#    Includes:
#    1. Measure Central Tandancy (Mean, Median, Mode)
#    2. Measure of dispersion (Variance, Standard Daviation)
#    3. Correlation, Covariance
#    4. Histograms, Pdf, Pmf, Cdf
#    5. Univariant, Bivariant analysis
#    6. Box plot
#
#    Pdf: Probability density funtion
#    Pmf: Probability Mass function
#    Cdf: Cumelative Density Function
# 2. Infrential Statistics:
#    -> Used for testing.
#    1. Hypothisis testing
#    2. z-test
#    3. T-test
#    4. Chi square test
#    5. anova (F-test)

# %% [markdown]
# # Variable
# - Types:
#   1. Quantitative:
#      1. Discrete Variable
#      2. Continuous Variables
#   2. Qualitative/ Categorical

# %% [markdown]
# # Percenile
# - A percentile is a value below which a certain percentage of the observation lies.
#
# eg:
# - 95 percentile means that the person has got better results than others.
#
# - percentile rank = (no of values below/n)*100
#
# eg:
# - What value exists at percentile rank of 25.
# - value = (percentile/100)(n+)

# %% [markdown]
# # Finding outliers
# - # Lower Fence
#     - Minimum value below which all data points are outliers.
#     - L.F = Q1 -1.5(IQR)     :.. IQR: Inter Quartile relathionship (Q3 - Q1)
# - # Higher Fence
#     - Maximum value above which all data points are outliers.
#     - - H.F = Q3 + 1.5(IQR)

# %% [markdown]
# # Z - Score
# - z_score = (xi-mean)/std

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = [1,4,5,7,3,9,100,5,8,105,5,8,8] 
q1, q3 = np.percentile(data, [25,75])
iqr = q3-q1
variance = np.var(data)
sd = np.std(data)
mean = np.mean(data)
print(f"Variance: {variance}")
print(f"STD: {sd}")
print(f"Mean: {mean}")
print(f"IQR: {iqr}")
print(q1,q3)

print(f"Lower fence: {q1-1.5*iqr}")
print(f"upper fence: {q3+1.5*iqr}")
print(sorted(data))
sns.boxplot(data)
# Out:
# Variance: 1224.8520710059174
# STD: 34.99788666485331
# Mean: 20.615384615384617
# IQR: 3.0
# 5.0 8.0
# Lower fence: 0.5
# upper fence: 12.5
# [1, 3, 4, 5, 5, 5, 7, 8, 8, 8, 9, 100, 105]
# <Axes: >

# %%
data1 = np.random.normal(loc = 50, scale = 10, size = 1000)
mean1 = np.mean(data1)
print(f"mean: {mean}")
variance = np.var(data1)
print(f"variance: {variance}")
std = np.std(data1)
threshold = 3 # 3rd std
print(f"Std: {std}")
outliers = []
# sns.boxplot(data1)
plt.axvline(mean, color = 'red')
plt.axvline(mean+std, color = 'g')
plt.axvline(mean-std, color = 'g')
plt.axvline(mean+2*std, color = 'b')
plt.axvline(mean-2*std, color = 'b')
plt.axvline(mean+3*std, color = 'b')
plt.axvline(mean-3*std, color = 'b')
plt.axhline(y = variance/1000, color = 'r',  linestyle = '--',linewidth = 4)
sns.histplot(data1)
# sns.kdeplot(data1, color = 'r')
# sns.lineplot(x = data1, y = np.sum(data1))
# sns.boxplot(data1)
# Out:
# mean: 20.615384615384617
# variance: 109.31097697696934
# Std: 10.455188997668543
# <Axes: ylabel='Count'>

# %%
for index, element in enumerate(data1):
    z_score = (element - mean1)/std
    if np.abs(z_score) > threshold:
        outliers.append(element)
        print(data1[index])
        data1[index] = mean1
# print(outliers)
# Out:
# 82.08146817535403

# %%
sns.boxplot(data1)
# Out:
# <Axes: >

# %%
plt.axvline(mean, color = 'red')
plt.axvline(mean+std, color = 'g')
plt.axvline(mean-std, color = 'g')
plt.axvline(mean+2*std, color = 'b')
plt.axvline(mean-2*std, color = 'b')
plt.axvline(mean+3*std, color = 'b')
plt.axvline(mean-3*std, color = 'b')
# plt.axhline(y = variance/2, color = 'r',  linestyle = '--',linewidth = 4)
sns.histplot(data1)
# sns.kdeplot(data1)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # PROBABLITY THEORY
#
#
#
# # Random Experiment
# - An experiment is called random experiment if it satisfies the following two
# - conditions:
#     1. It has more than one possible outcome.
#     2. It is not possible to predict the outcome in advance

# %% [markdown]
# **For Example**,
# 1. Roll 2 six sided dice at once.

# %% [markdown]
# # Trial
# - Trial refers to a single execution of a random experiment. Each trial produces an
# outcome.

# %% [markdown]
# # Outcome
# - Outcome refers to a single possible result of a trial.

# %% [markdown]
# # Sample Space
# - Sample Space of a random experiment is the set of all possible outcomes that can occur.
# - Generally, one random experiment will have one set of sample space.

# %% [markdown]
# # Event
# - Event is a specific set of outcomes from a random experiment or process.
# - Essentially, it's a subset of the sample space.
# - An event can include a single outcome, or it can include multiple outcomes.
# - One random experiments can have multiple events.

# %%
dice_roll = {1,2,3,4,5,6}  # Sample Space
event =  3 # event
coin_toss = {'H','T'}
event = 'H'

# %% [markdown]
# # Example
# 1. Rolling a die
# 2. Tossing a coin twice
# 3. Titanic example

# %%
Toss_coin_twice = {'HH','HT','TH','TT'}
event = 'TH'

# %% [markdown]
# # Type of Events
# ## 1. Simple Event:
#    - Also known as an elementary event, a simple event is an event that consists of exactly one outcome.
#    - ***For example***, when rolling a fair six-sided die, getting a 3 is a simple event.
# ## 2. Compound Event:
#    - A compound event consists of two or more simple events.
#    - ***For example***, when rolling a die, the event "rolling an odd number" is a compound event <br>
#     because it consists of three simple events: rolling a 1, rolling a 3, or rolling a 5.
# ## 3. Independent Events:
#    - Two events are independent if the occurrence of one event does not <br> affect the probability of the occurrence of the other event.
#    - ***For example***, if you flip a coin and roll a die, <br>the outcome of the coin flip does not affect the
#     outcome of the die roll.
# ## 4. Dependent Events:
#    - Events are dependent if the occurrence of one event affect the <br>probability of the occurrence of the other event.
#    - ***For example***, if you draw two cards from a deck without replacement, the outcome of the <br> first draw affects the outcome of the second draw because there are fewer cards left in the
# deck.
# ## 5. Mutually Exclusive Events:
#     - Two events are mutually exclusive (or disjoint) <br>if they cannot both occur at the same time.<br>
#     ***For example***, when rolling a die, the events "roll a 2" and "roll a 4" are mutually exclusive <br>because a single roll of the die cannot result in both a 2 and a 4.
# ## 6. Exhaustive Events:
#    - A set of events is exhaustive if at least one of the events must occur <br>when the experiment is performed.
#    - ***For example***, when rolling a die, the events "roll an even number" and "roll an odd <br>number" are exhaustive because one or the other must occur on any roll.
# ## 7. Impossible event and Certain Event.

# %%
# you have total of 10 bolls in a bag 4 are white and other are of black in color.

# %% [markdown]
# # What is Probability
# - In simplest terms, probability is a measure of the likelihood that a particular event will occur. It <br>is a fundamental concept in statistics and is used to make predictions and informed decisions <br>in a wide range of disciplines, including science, engineering, medicine, economics, and social
# sciences.
#
# **Probability is usually expressed as a number between 0 and 1, inclusive:**
# - A probability of 0 means that an event will not happen.
# - A probability of 1 means that an event will certainly happen.
# - A probability of 0.5 means that an event will happen half the time (or that it is as likely to happen as not to happen).

# %% [markdown]
# # Empirical Probability Vs Theoretical Probability
# ## Empirical Probability
# Empirical probability, also known as experimental probability, is a probability measure that is based on observed data, rather than theoretical assumptions. It's calculated as the ratio of the number of times a particular event occurs to the total number of trials. <br>
# - No of times the event occurs/total no of trails<br>
# ***For example***,
#   1. Suppose that, in our 100 tosses, we get heads 55 times and tails 45 times. What is the empirical
# probability of getting a head.
#   2. Let's say you have a bag with 50 marbles. Out of these 50 marbles, 20 are red, 15 are blue, and 15 are
# green. You start to draw marbles one at a time, replacing the marble back into the bag after each draw. After 200 draws, you find that you've drawn a  red marble 80 times, a blue marble 70 times, and a green marble 50 times. What is the empirical probability of getting a red marble?
# ## Theoretical Probability
# Theoretical (or classical) probability is used when each outcome in a sample space is equally likely to occur. If we denote an event of interest as Event A, we calculate the theoretical probability of that event as:
# - Theoretical Probability of Event A = Number of Favourable Outcomes (that is, outcomes in Event A) / Total Number of Outcomes in the Sample Space
# - Total no of events/total no of pssible outcomes<br>
# ***For Example***,
#   1. Consider a scenario of tossing a fair coin 3 times. Find the probability of getting exactly 2 heads.
#   2. Consider a scenario of rolling 2 dice. What is the probability of getting a sum = 7

# %%
# coin toss
# theoritical probability
# ss = {'H','T'}

# toss a coin 100 times simulate in python
ss1 = np.random.choice(['H','T'], size = 150)
ss1 = pd.Series(ss1)
print(f"Theoritical Probability of H: {1/len(ss1.unique())}")
print(f" Emerical probability {ss1.value_counts(normalize = True)['H']}")
print(ss1.value_counts()['H']/150)
# Scenario: A bag has 3 red balls, 5 blue balls, 2 green balls.
# Theoritical Probability of picking a blue ball.
# Emperical: Simulate drawing 10000 balls randomly. extimate the probability and compare with others.
ss = ['red']*3+['blue']*5+['green']*2
ss = pd.Series(ss)
print(f"Theoritical Probability of blue ball: {ss.value_counts()['blue']/len(ss)}")
trails = 10000
round_value = np.random.choice(ss,size = trails)
round_value = pd.Series(round_value)
for ball in ss.unique():
    print(f"Emperical Probability of {ball}: {round_value.value_counts(normalize = True)[ball]:.2f}")
sns.barplot(x = round_value.value_counts(normalize = True).index, y=round_value.value_counts(normalize = True).values, 
            hue = round_value.value_counts(normalize = True).index)
sns.lineplot(ss.value_counts()/len(ss), color = 'r', marker = 'o')
# Out:
# Theoritical Probability of H: 0.5
#  Emerical probability 0.5733333333333334
# 0.5733333333333334
# Theoritical Probability of blue ball: 0.5
# Emperical Probability of red: 0.31
# Emperical Probability of blue: 0.49
# Emperical Probability of green: 0.20
# <Axes: xlabel='None', ylabel='count'>

# %% [markdown]
# # Random Variable
# In the context of probability theory, a random variable is a function that maps the
# outcomes of a random process (known as the sample space) to a set of real numbers.<br>
# **Input:** The input to the function is an outcome from the sample space of a random
# process.<br>
# **Output:** The output of the function is a real number that we assign to each possible
# outcome.
# - The transformation from input to output in the function of a random variable is
# determined by how we choose to define the random variable.
# And the choice of how to define a random variable often depends on the specific aspects
# of the random process (or event) that you're interested in studying.

# %%
# experiment: roll a dice twice and find the probability of pair = 7
# trail: 100 times and find emperical probability of pairs getting sum of 7
np.random.seed(42)
trails = 150
dice_1 = np.random.randint(1,7, size = trails)
dice_2 = np.random.randint(1,7, size = trails)

value_x = dice_1 + dice_2
value_7 = (value_x == 7)
print(value_7.sum())

print(f"Theoritical probability {6/36}")
print(f"emperical probability {value_7.sum()/trails}")

plt.hist(value_x, bins=np.arange(2,14))
plt.axvline(7, color = 'r')
# Out:
# 24
# Theoritical probability 0.16666666666666666
# emperical probability 0.16

# %% [markdown]
# # 1) Probability Distribution Function
# # 2) Probability Density Function
# A Probability Density Function (PDF) is a function that describes the relative likelihood of a continuous random variable taking on a particular value.
# - Key Points:<br>
#     1) For Continuous Variables
#        - Unlike discrete variables (where we use a Probability Mass Function PMF), continuous variables don’t have probability at exact points.
#        - Instead, probability is given over intervals.
#     2) Area Under Curve = Probability
#        - The total area under the PDF curve = 1 (100%).
#        - Probability that the variable falls in an interval [a, b] is the area under the curve between a and b.
# # 3) Probability Mass Function
# A Probability Mass Function (PMF) applies to discrete random variables.<br>
# It gives the probability that the random variable is exactly equal to a specific value.
# - Key Points:
#     1) For Discrete Variables
#        - Works when outcomes are countable (e.g., dice rolls, coin flips, number of customers).
#     2) Definition
#        - For a discrete random variable X, the PMF is:  𝑃(𝑋=𝑥)=𝑓(𝑥)
#        - where: 𝑓(𝑥)≥0  and ∑f(x)=1
#     3) Examples
#        - A fair die: P(X=x)=1/6,  x=1,2,3,4,5,6
#        - A coin flip:P(X=Heads)=0.5,  P(X=Tails)=0.5
# # 4) Comulative Density Function
# The Cumulative Distribution Function (CDF) gives the probability that a random variable X is less than or equal to a certain value.

# %% [markdown]
# # Task 1: PMF (Discrete Probability) 🎲
#     Scenario: You roll a fair 6-sided die many times.
# - Steps:
#     1. Simulate 10,000 dice rolls using numpy.random.randint().
#     2. Count the occurrences of each outcome (1 to 6).
#     3. Convert counts into probabilities: 𝑃(𝑋=𝑥)=Count of outcome x / Total rolls
#     4. Store the results in a dictionary (like {1: 0.16, 2: 0.17, ...}).
#     5. Plot the PMF using Matplotlib bar plot (x = dice numbers, y = probabilities).

# %%
trails = 10000
rolls = np.random.randint(1,7, size= trails)
value, counts = np.unique(rolls, return_counts=True)
p_count = counts/trails

pmf = dict(zip(value,p_count))

plt.bar(value, p_count)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Task 2 PDF (Continuous Probability) 🔔
#     Scenario: Heights of people usually follow a Normal Distribution.
# - Steps:
#     1. Generate 10,000 random values from a normal distribution with numpy.random.normal(loc=0, scale=1, size=10000).
#     2. Mean = 0, Standard deviation = 1.
#     3. Plot a histogram with density=True to approximate the PDF.
#     4. Overlay the theoretical PDF curve using scipy.stats.norm.pdf(x, mean, std).
